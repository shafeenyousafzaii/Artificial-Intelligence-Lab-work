# %%
import pandas as pd
import numpy as np
df=pd.read_csv("/home/shafeen/Documents/My-all-programs--/Semester-4/Aritificial Intelligence/Lab-02/Auto85.csv")
df=pd.DataFrame(df)
df
# Out:
#      3    ?  alfa-romero     gas    std   two  convertible  rwd  front  88.60  \
# 0    3    ?  alfa-romero     gas    std   two  convertible  rwd  front   88.6
# 1    1    ?  alfa-romero     gas    std   two    hatchback  rwd  front   94.5
# 2    2  164         audi     gas    std  four        sedan  fwd  front   99.8
# 3    2  164         audi     gas    std  four        sedan  4wd  front   99.4
# 4    2    ?         audi     gas    std   two        sedan  fwd  front   99.8
# ..  ..  ...          ...     ...    ...   ...          ...  ...    ...    ...
# 199 -1   95        volvo     gas    std  four        sedan  rwd  front  109.1
# 200 -1   95        volvo     gas  turbo  four        sedan  rwd  front  109.1
# 201 -1   95        volvo     gas    std  four        sedan  rwd  front  109.1
# 202 -1   95        volvo  diesel  turbo  four        sedan  rwd  front  109.1
# 203 -1   95        volvo     gas  turbo  four        sedan  rwd  front  109.1
#
# ...

# %%
headers = ["symboling","normalized-losses","make","fuel-type",
           "aspiration", "num-of-doors", "body-style", "drive-wheels",
           "engine-location", "wheel-base", "length", "width", "height",
           "curb-weight", "engine-type", "num-of-cylinders", "engine-size",
           "fuel-system", "bore", "stroke", "compression-ratio", "horsepower",
           "peak-rpm", "city-mpg", "highway-mpg", "Price"]
df.columns=headers
df
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            1                 ?  alfa-romero       gas        std
# 2            2               164         audi       gas        std
# 3            2               164         audi       gas        std
# 4            2                 ?         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 199         -1                95        volvo       gas        std
# 200         -1                95        volvo       gas      turbo
# 201         -1                95        volvo       gas        std
# 202         -1                95        volvo    diesel      turbo
# 203         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
pricedf=df[["Price"]]
pricedf
# Out:
#      Price
# 0    16500
# 1    16500
# 2    13950
# 3    17450
# 4    15250
# ..     ...
# 199  16845
# 200  19045
# 201  21485
# 202  22470
# 203  22625
#
# [204 rows x 1 columns]

# %%
# pricedf.ffill()
# pricedf.isnull()
pricedf.head(10)
# Out:
#    Price
# 0  16500
# 1  16500
# 2  13950
# 3  17450
# 4  15250
# 5  17710
# 6  18920
# 7  23875
# 8      ?
# 9  16430

# %%
pricedf.replace('?',np.nan,inplace=True)
pricedf["Price"]=pd.to_numeric(pricedf["Price"])
mean=pricedf.mean()
pricedf.replace(np.nan,mean,inplace=True)
# Out:
# /tmp/ipykernel_10017/1983895379.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pricedf.replace('?',np.nan,inplace=True)
# /tmp/ipykernel_10017/1983895379.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pricedf["Price"]=pd.to_numeric(pricedf["Price"])
# /tmp/ipykernel_10017/1983895379.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
pricedf.head(10)
# Out:
#       Price
# 0  16500.00
# 1  16500.00
# 2  13950.00
# 3  17450.00
# 4  15250.00
# 5  17710.00
# 6  18920.00
# 7  23875.00
# 8  13205.69
# 9  16430.00

# %%
a=np.linspace(-2,2,5)
a
# Out:
# array([-2., -1.,  0.,  1.,  2.])

# %%
b=np.linspace(0,2*np.pi,10)
b
# Out:
# array([0.        , 0.6981317 , 1.3962634 , 2.0943951 , 2.7925268 ,
#        3.4906585 , 4.1887902 , 4.88692191, 5.58505361, 6.28318531])

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
c=np.sin(b)
plt.title("SIN CURVE")
plt.xlabel("No of Values")
plt.ylabel("Range")
plt.plot(c)

# %%
# c=np.linspace(0)

# %%
aa=np.random.randn(100)
aa
plt.hist(aa,bins=10)
# Out:
# (array([ 4.,  7.,  9., 15., 14., 12., 15., 14.,  8.,  2.]),
#  array([-2.24754897, -1.79929268, -1.35103639, -0.90278011, -0.45452382,
#         -0.00626754,  0.44198875,  0.89024504,  1.33850132,  1.78675761,
#          2.2350139 ]),
#  <BarContainer object of 10 artists>)

# %%
# %pip install
