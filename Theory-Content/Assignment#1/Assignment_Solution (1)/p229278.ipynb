# %% [markdown]
# ### Name         : Muhammad Shafeen
# ### ID           : 22P-9278
# ### Assignment # : 1

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def file_reading(Filepath,input1): # This function is to read the file and choose whether user wants to open the file with read command or write command
        concat="/home/shafeen/Documents/My-all-programs--/Semester-4/Aritificial Intelligence/Theory-Content/Assignment#1/Assignment_Solution/"+Filepath
        try:    # using try and except for better handling of errors
            if input1.upper()=="W":  # checks if it in write then write if not then read
                # concat="/home/shafeen/Documents/My-all-programs--/Semester-4/Aritificial Intelligence/Theory-Content/Assignment#1/Assignment_Solution/"+Filepath
                file = open(concat,"w")
            else:
                # concat="/home/shafeen/Documents/My-all-programs--/Semester-4/Aritificial Intelligence/Theory-Content/Assignment#1/Assignment_Solution/"+Filepath
                file = open(concat,"r")
        except:
            print("File not Found to read")
            # exit
        try:
            if input1 == "W": # checks if it in write then write if not then read
                file_write=str(input("Write what you want to write in the file"))
                file.write(file_write)
        except:
            print("File not found to write") 
        file.close() #closing the file
        try:
            file =open(Filepath,"r")
            for x in file:
                print(x)
        except:
            print("File not found to print")
def Calculating_ARI(character,words,sentences): #Calculating the ARI 
    ARI=4.71*(character/words)
    ARI=ARI+(0.5*(words/sentences)-21.43)
    if ARI < 0:
        ARI=0
    return ARI
def Number_Of_Sentences(path): # Finding the number of sentences
    concat="/home/shafeen/Documents/My-all-programs--/Semester-4/Aritificial Intelligence/Theory-Content/Assignment#1/Assignment_Solution/"+path
    # count=0
    # for i in whole_text:
    #     if i == ".":
    #         count=count+1
    try:
        try:
            text_file=open(concat,"r")
        except:
            print("File Not Found")
            return
        text=text_file.read()
        text_list=text.replace('\n',' ').split("!")
        text_list1=text.replace('\n',' ').split(".")
        text_list2=text.replace('\n',' ').split(":")
        text_list3=text.replace('\n',' ').split(";")
        text_list4=text.replace('\n',' ').split("?")
        # print(text_list)  For Testing Basis
        # print(text_list1) // 
        # print(text_list2) // 
        # print(text_list3) //
        # print(text_list4) //
        NO_OF_SENTENCES=len(text_list)-1
        NO_OF_SENTENCES=NO_OF_SENTENCES + len(text_list1)-1
        NO_OF_SENTENCES=NO_OF_SENTENCES + len(text_list2)-1
        NO_OF_SENTENCES=NO_OF_SENTENCES + len(text_list3)-1
        NO_OF_SENTENCES=NO_OF_SENTENCES + len(text_list4)-1
        # print(NO_OF_SENTENCES)
        text_file.close()
        return NO_OF_SENTENCES
    except:
        print("File Not found")
def counting_characters(file_path): # a function for counting the characters and separating all the punctuations
        text_file="/home/shafeen/Documents/My-all-programs--/Semester-4/Aritificial Intelligence/Theory-Content/Assignment#1/Assignment_Solution/"+file_path
        try:
            text_file=open(text_file,"r")
        except:
            print("File Not Found")
            return
        text=text_file.read()
        Punctuations = [
            (".",""),
            (",",""),
            ("?",""),
            ("!",""),
            (";",""),
            (":",""),
            ("-",""),
            ("_",""),
            ("+",""),
            ("=",""),
            (")",""),
            ("(",""),
            ("*",""),
            ("&",""),
            ("^",""),
            ("%",""),
            ("$",""),
            ("#",""),
            ("@",""),
            ("[",""),
            ("]",""),
            ("{",""),
            ("}",""),
            ("<",""),
            (">",""),
            ("|",""),
            ("/",""),
            ("!",""),
            ("`"," "),
            ("~",""), 
            (" ",""), 
            ("\n",""), 
            ("’",""),
            ("''",""),
            ("...",""),
            # ("`"," "), 
        ]
        for i,j in Punctuations:
            text=text.replace(i,j)
        # print(text)
        count=0
        # print(text)
        count=len(text)
        # print(count)
        # print(type(text))
        text_file.close()
        return count

def Counting_words(file_path):
        text_file="/home/shafeen/Documents/My-all-programs--/Semester-4/Aritificial Intelligence/Theory-Content/Assignment#1/Assignment_Solution/"+file_path
        try:
            text_file=open(text_file,"r")
        except:
            print("File Not Found")
            return
        text=text_file.read()
        Punctuationss=[
            ("."," "),
            # # (";",""),
            # (":",""),
            # ("?",""),
            # ("!",""),
            # ("-","t"),
            # ("’"," "),
            ("\n"," "),
            ("-"," "),
            ("’"," ")
        ]
        for i,j in Punctuationss:
            text_list=text.replace(i,j).split()
        # print(len(text_list))
        # print(text_list)
        text_file.close()
        return len(text_list)
        # choice=0
def compute_all(file_path):
    text_file="/home/shafeen/Documents/My-all-programs--/Semester-4/Aritificial Intelligence/Theory-Content/Assignment#1/Assignment_Solution/"+file_path
    try:
        text_file=open(text_file,"r")
    except:
        print("File Not Found")
        return
    Words=Counting_words(file_path)
    Character=counting_characters(file_path)
    Sentences=Number_Of_Sentences(file_path)
    ARII=Calculating_ARI(Character,Words,Sentences)
    print("Number of Sentences : ",Sentences)
    print("NUmber of Words     : ",Words)
    print("Number of Characters: ",Character)
    print("Readability Index   : ",round(ARII))
choice=0
while(choice!="7"):
    All_files=["Example 1","Example 2","Example 3","Example 4","Text File 1","Text File 2","Text File 3"]
    print("Choose from the following : Press (1-6) ")
    # print("1) Write in a new file") # Make a file in wrtie mode and write something in it
    print("1) Read a file") # Read a file in R mode and read from it
    print("2) Number of Sentences") # Just the number of senetences
    print("3) Number of words") # JUst the number of words
    print("4) Number of characters") #Just the number of characters
    print("5) Compute All of the tasks Required All toghether along with its ARI ")
    print("6) Exit") #Exit
    choice=input()
    # if choice == "1":
    #     print("First Enter File Path")
    #     file_path=str(input("Enter File Name"))
    #     file_reading(file_path,"W")
    if choice == "1":
        print("First Enter File Path")
        file_path=str(input("Enter File Name"))
        file_reading(file_path,"R")
    elif choice=="2":
        # print("First Enter File Path")
        # file_path=str(input("Enter File Name"))
        # x=Number_Of_Sentences(file_path)
        # print("The number of sentences this Text has : ",x)
        for i in All_files:
            print("File : ",i)
            conut=Number_Of_Sentences(i)
            print("The number of Sentences this Text has : ",conut)
    elif choice == "3":
        # print("First Enter File Path")
        # file_path=str(input("Enter File Name : "))
        # conut=Counting_words(file_path)
        for i in All_files:
            print("File : ",i)
            conut=Counting_words(i)
            print("The number of Words this Text has : ",conut)
    elif choice=="4":                                                                  ## Dont need these lines now... so commented them out
        # print("First Enter File Path")
        # file_path=str(input("Enter File Name : "))
        for i in All_files:
            print("File : ",i)
            conut=counting_characters(i)
            print("The number of Characters this Text has : ",conut)
    elif choice=="5":
        print("First Enter File Path")
        # file_path=str(input("Enter File Name"))
        for i in All_files:
            print("File : ",i)
            compute_all(i)
    else:
        break
# Out:
# Choose from the following : Press (1-6)
# 1) Read a file
# 2) Number of Sentences
# 3) Number of words
# 4) Number of characters
# 5) Compute All of the tasks Required All toghether along with its ARI
# 6) Exit
# File :  Example 1
# The number of Sentences this Text has :  1
# File :  Example 2
# The number of Sentences this Text has :  3
# File :  Example 3
# The number of Sentences this Text has :  3
# File :  Example 4
# The number of Sentences this Text has :  1
# File :  Text File 1
# The number of Sentences this Text has :  2
# File :  Text File 2
# The number of Sentences this Text has :  3
# File :  Text File 3
# The number of Sentences this Text has :  3
# Choose from the following : Press (1-6)
# 1) Read a file
# 2) Number of Sentences
# 3) Number of words
# 4) Number of characters
# 5) Compute All of the tasks Required All toghether along with its ARI
# 6) Exit
# File :  Example 1
# The number of Words this Text has :  30
# File :  Example 2
# ...

# %% [markdown]
# ## NUMBER OF SENTENCES CHECKING

# %%
All_files=["Example 1","Example 2","Example 3","Example 4","Text File 1","Text File 2","Text File 3"]
for i in All_files:
    print("File : ",i)
    text_file="/home/shafeen/Documents/My-all-programs--/Semester-4/Aritificial Intelligence/Theory-Content/Assignment#1/Assignment_Solution/"+i
    try:
        text_file=open(text_file,"r")
    except:
        print("File Not Found")
    text=text_file.read()
    text_list=text.replace('\n',' ').split("!")
    text_list1=text.replace('\n',' ').split(".")
    text_list2=text.replace('\n',' ').split(":")
    text_list3=text.replace('\n',' ').split(";")
    text_list4=text.replace('\n',' ').split("?")
    # print(text_list)  For Testing Basis
    # print(text_list1) // 
    # print(text_list2) // 
    # print(text_list3) //
    # print(text_list4) //
    NO_OF_SENTENCES=len(text_list)-1
    NO_OF_SENTENCES=NO_OF_SENTENCES + len(text_list1)-1
    NO_OF_SENTENCES=NO_OF_SENTENCES + len(text_list2)-1
    NO_OF_SENTENCES=NO_OF_SENTENCES + len(text_list3)-1
    NO_OF_SENTENCES=NO_OF_SENTENCES + len(text_list4)-1
    print("Number Of Sentences : ",NO_OF_SENTENCES)
    text_file.close()
# Out:
# File :  Example 1
# Number Of Sentences :  1
# File :  Example 2
# Number Of Sentences :  3
# File :  Example 3
# Number Of Sentences :  3
# File :  Example 4
# Number Of Sentences :  1
# File :  Text File 1
# Number Of Sentences :  2
# File :  Text File 2
# Number Of Sentences :  3
# File :  Text File 3
# Number Of Sentences :  3

# %% [markdown]
# ## NUMBER OF CHARACTERS CHECKING

# %%
Punctuations = [
    (".",""),
    (",",""),
    ("?",""),
    ("!",""),
    (";",""),
    (":",""),
    ("-",""),
    ("_",""),
    ("+",""),
    ("=",""),
    (")",""),
    ("(",""),
    ("*",""),
    ("&",""),
    ("^",""),
    ("%",""),
    ("$",""),
    ("#",""),
    ("@",""),
    ("[",""),
    ("]",""),
    ("{",""),
    ("}",""),
    ("<",""),
    (">",""),
    ("|",""),
    ("/",""),
    ("",""),
    ("!",""),
    (";",""),
    ("`",""),
    ("~",""), 
    (" ",""), 
    ("\n",""), 
]
All_files=["Example 1","Example 2","Example 3","Example 4","Text File 1","Text File 2","Text File 3"]
for i in All_files:
    print("File : ",i)
    text_file="/home/shafeen/Documents/My-all-programs--/Semester-4/Aritificial Intelligence/Theory-Content/Assignment#1/Assignment_Solution/"+i
    try:
        text_file=open(text_file,"r")
    except:
        print("File Not Found")
        # return
    # text_file=open("/home/shafeen/Documents/My-all-programs--/Semester-4/Aritificial Intelligence/Theory-Content/Assignment#1/Assignment_Solution/Testing","r")
    text=text_file.read()
    for i,j in Punctuations:
        text=text.replace(i,j)
    count=0
    print("Number of Characters : ",len(text))
    # print(text)
    # count=len(text)
    # print(count)
    # print(type(text))
    text_file.close()
# Out:
# File :  Example 1
# Number of Characters :  134
# File :  Example 2
# Number of Characters :  92
# File :  Example 3
# Number of Characters :  3
# File :  Example 4
# Number of Characters :  30
# File :  Text File 1
# Number of Characters :  23
# File :  Text File 2
# Number of Characters :  126
# File :  Text File 3
# Number of Characters :  499

# %% [markdown]
# ## NUMBER OF WORDS TESTING

# %%
All_files=["Example 1","Example 2","Example 3","Example 4","Text File 1","Text File 2","Text File 3"]
for i in All_files:
    print("File : ",i)
    text_file="/home/shafeen/Documents/My-all-programs--/Semester-4/Aritificial Intelligence/Theory-Content/Assignment#1/Assignment_Solution/"+i
    try:
        text_file=open(text_file,"r")
    except:
        print("File Not Found")
        # return
    text=text_file.read()
    Punctuationss=[
        ("."," "),
        # # (";",""),
        # (":",""),
        # ("?",""),
        # ("!",""),
        # ("-","t"),
        # ("’"," "),
        ("\n"," "),
        ("-"," "),
        ("’"," ")
    ]
    for i,j in Punctuationss:
        text_list=text.replace(i,j).split()
    print("Number of Words : ",len(text_list))
    # print(text_list)
    text_file.close()
    # print(len(text_list))
# choice=0
# Out:
# File :  Example 1
# Number of Words :  30
# File :  Example 2
# Number of Words :  23
# File :  Example 3
# Number of Words :  1
# File :  Example 4
# Number of Words :  6
# File :  Text File 1
# Number of Words :  7
# File :  Text File 2
# Number of Words :  31
# File :  Text File 3
# Number of Words :  125

# %% [markdown]
# ## PRACTICE

# %%
# text_file="Test File 4"
# try:
# try:
text_file=open("/home/shafeen/Documents/My-all-programs--/Semester-4/Aritificial Intelligence/Theory-Content/Assignment#1/Assignment_Solution/Text File 3","r")
# except:
    # print("File Not Found")
# text=text_file.read()
# for x in text:
#     print(text)
text=text_file.read()
Punctuationss=[
    ("."," "),
    ("\n"," "),
    ("-"," "),
    ("’"," "),
    (","," "),
    
    # # (";",""),
    # (":",""),
    # ("?",""),
    # ("!",""),
    # ("-","t"),
    # ("’"," "),
]
for i,j in Punctuationss:
    # print(i)
    text_list=text.replace(i,j).split()
    # count=count+1
# text_list=text.split()
# text_list=text.replace('\n',' ').split(" ")
# text_list1=text.replace('\n',' ').split(".")
# text_list2=text.replace('\n','').split("\n")
# text_list3=text.replace('\n',' ').split(";")
# text_list4=text.replace('\n',' ').split("?")
print(len(text_list))
print(text_list)
# print(len(text_list1))
# print(text_list1)
# print(text_list2)
# # print(text_list3)
# print(text_list4)
# NO_OF_SENTENCES=len(text_list)-1
# NO_OF_SENTENCES=NO_OF_SENTENCES + len(text_list1)-1
# NO_OF_SENTENCES=NO_OF_SENTENCES + len(text_list2)-1
# NO_OF_SENTENCES=NO_OF_SENTENCES + len(text_list3)-1
# NO_OF_SENTENCES=NO_OF_SENTENCES + len(text_list4)-1
# print(NO_OF_SENTENCES)
text_file.close()
# return NO_OF_SENTENCES
# text_list=text.replace("\n.!?"," ").split(".!?")
# print(text_list)

# text_file.close()
# except:
#         print("File Not found")
# Out:
# 125
# ...

# %%
# text_file="Test File 4"
# try:
# try:
text_file=open("/home/shafeen/Documents/My-all-programs--/Semester-4/Aritificial Intelligence/Theory-Content/Assignment#1/Assignment_Solution/Testing","r")
# except:
    # print("File Not Found")
text=text_file.read()
# for x in text:
#     print(text)
Punctuations = [
    (".",""),
    (",",""),
    ("?",""),
    (" ",""), 
    ("!",""),
    (";",""),
    (":",""),
    ("-",""),
    ("_",""),
    ("+",""),
    ("=",""),
    (")",""),
    ("(",""),
    ("*",""),
    ("&",""),
    ("^",""),
    ("%",""),
    ("$",""),
    ("#",""),
    ("@",""),
    ("[",""),
    ("]",""),
    ("{",""),
    ("}",""),
    ("<",""),
    (">",""),
    ("|",""),
    # ("/",""),
    ("",""),
    ("!",""),
    (";",""),
    ("~",""), 
    ("`"," "),
    ("'",""),
    ("\n","")
]
text_list=[[]]
for i,j in Punctuations:
    # print(i,j)
    # print(i)
    text_list.append(text.replace(i,j).split("!"))
    text_list1=text.replace(i,j).split()
    # print(text)
# text_list=text.replace("\n"," ")
# text_list1=text_list.replace(".","")
# text_list2=text_list1.replace(" ","")
# text_list3=text_list2.replace(",","")
# text_list4=text_list3.replace("?","")
# text_list5=text_list4.replace("!","")
# text_list5=text_list4.replace("!","")
# count=0
print(text_list1)
print(text_list)
count=len(text_list)
print(count)
print(len(text_list1))
print(type(text))
text_file.close()
# except:
#         print("File Not found")
# Out:
# ['There', 'was', 'once', 'a', 'poor', 'servant-girl,', 'who', 'was', 'industrious', 'and', 'cleanly,and', 'swept', 'the', 'house', 'every', 'day,', 'and', 'emptied', 'her', 'sweepings', 'on', 'the', 'great', 'heap', 'in', 'front', 'ofthe', 'door.', 'One', 'morning', 'when', 'she', 'was', 'just', 'going', 'back', 'to', 'her', 'work,', 'she', 'found', 'a', 'letter', 'onthis', 'heap,', 'and', 'as', 'she', 'could', 'not', 'read,', 'she', 'put', 'her', 'broom', 'in', 'the', 'corner,', 'and', 'took', 'theletter', 'to', 'her', 'master', 'and', 'mistress,', 'and', 'behold', 'it', 'was', 'an', 'invitation', 'from', 'the', 'elves,who', 'asked', 'the', 'girl', 'to', 'hold', 'a', 'child', 'for', 'them', 'at', 'its', 'christening.', 'The', 'girl', 'did', 'not', 'knowwhat', 'to', 'do,', 'but', 'at', 'length,', 'after', 'much', 'persuasion,', 'and', 'as', 'they', 'told', 'her', 'that', 'it', 'was', 'notright', 'to', 'refuse', 'an', 'invitation', 'of', 'this', 'kind,', 'she', 'consented.']
# ...

# %%
def Number_Of_Sentences(path): # Finding the number of sentences
    concat="/home/shafeen/Documents/My-all-programs--/Semester-4/Aritificial Intelligence/Theory-Content/Assignment#1/Assignment_Solution/"+path
    # count=0
    # for i in whole_text:
    #     if i == ".":
    #         count=count+1
    try:
        try:
            text_file=open(concat,"r")
        except:
            print("File Not Found")
            return
        text=text_file.read()
        text_list=text.replace('\n',' ').split(".",":",";","!","?")
        print(text_list)
        NO_OF_SENTENCES=len(text_list)
        print(NO_OF_SENTENCES)
        text_file.close()
        return NO_OF_SENTENCES
    except:
        print("File Not found")

# %% [markdown]
# ## REFERENCE FROM REALPYTHON.COM

# %%
# transcript_multiple_replace.py

REPLACEMENTS = [
    ("BLASTED", "😤"),
    ("Blast", "😤"),
    ("2022-08-24T", ""),
    ("+00:00", ""),
    ("[support_tom]", "Agent "),
    ("[johndoe]", "Client"),
]

transcript = """
[support_tom] 2022-08-24T10:02:23+00:00 : What can I help you with?
[johndoe] 2022-08-24T10:03:15+00:00 : I CAN'T CONNECT TO MY BLASTED ACCOUNT
[support_tom] 2022-08-24T10:03:30+00:00 : Are you sure it's not your caps lock?
[johndoe] 2022-08-24T10:04:03+00:00 : Blast! You're right!
"""

for old, new in REPLACEMENTS:
    transcript = transcript.replace(old, new)

print(transcript)
# Out:
# Agent  10:02:23 : What can I help you with?
# Client 10:03:15 : I CAN'T CONNECT TO MY 😤 ACCOUNT
# Agent  10:03:30 : Are you sure it's not your caps lock?
# Client 10:04:03 : 😤! You're right!
